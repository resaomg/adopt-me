# %% [markdown]
# <a href="https://colab.research.google.com/github/resaomg/adopt-me/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Клонируем репозиторий ComfyUI
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI

# Устанавливаем необходимые зависимости
# !pip install -r requirements.txt
# !pip install xformers

# Устанавливаем ComfyUI-Manager (для удобной доустановки узлов)
# %cd custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager
# %cd ..
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 41885, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 41885 (delta 97), reused 38 (delta 38), pack-reused 41749 (from 2)
# Receiving objects: 100% (41885/41885), 83.41 MiB | 17.48 MiB/s, done.
# Resolving deltas: 100% (28326/28326), done.
# /content/ComfyUI
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 94.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 MB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 9.2 MB/s eta 0:00:00
# ...

# %%
# 1. Скачиваем проверенный FLUX.1-dev (в формате Q4 GGUF для экономии видеопамяти)
# !hf download city96/FLUX.1-dev-gguf flux1-dev-Q4_K_S.gguf --local-dir models/unet

# 2. Скачиваем главный текстовый энкодер T5 (в сжатом формате fp8)
# !hf download comfyanonymous/flux_text_encoders t5xxl_fp8_e4m3fn.safetensors --local-dir models/clip

# 3. Скачиваем популярную Uncensored LoRA напрямую в папку лор
# !hf download ptx0/flux-1-dev-uncensored flux-1-dev-uncensored.safetensors --local-dir models/loras
# Out:
# ✓ Downloaded
#   path: /content/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf
# Error: Repository not found. If the repo is private, make sure you are authenticated and your token has the required permissions.
# Set HF_DEBUG=1 as environment variable for full traceback.

# %%
# 1. Устанавливаем ngrok
# !pip install pyngrok > /dev/null 2>&1

from pyngrok import ngrok, conf

# 2. Устанавливаем твой токен (замени строку на свой)
auth_token = "2SG3ufYw0ISMBeV47vBlgVxu8fe_7eF2BwfSs3Ru6yj8Zc8Yv"
ngrok.set_auth_token(auth_token)

# 3. Открываем туннель на порт 8188 (стандартный для ComfyUI)
public_url = ngrok.connect(8188, "http")

print("====================================================")
print(f"✅ ТВОЯ СТАБИЛЬНАЯ ССЫЛКА: {public_url.public_url}")
print("====================================================")

# 4. Запускаем сервер
# !python main.py --dont-print-server
# Out:
# ...
# ✅ ТВОЯ СТАБИЛЬНАЯ ССЫЛКА: https://6929-34-16-225-17.ngrok-free.app
# ...
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-06-28 22:35:37.375
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# [INFO]
# Prestartup times for custom nodes:
# ...

# %%
# !rm /content/ComfyUI/models/unet/flux2-klein-9b-q4.gguf
